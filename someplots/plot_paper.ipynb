# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the image
countries = ["Brasil", "Argentina", "Uruguay", "Chile", "Bolivia", "Ecuador", "Colombia", "Peru", "Paraguay"]
values = [33.3, 29.6, 26.6, 23.9, 23.7, 20.9, 19.7, 19.2, 14.7]

# Normalize values for a grayscale gradient effect
normalized_values = (np.array(values) - min(values)) / (max(values) - min(values))

# Create grayscale shades based on values
colors = [(0.2 + 0.6 * norm, 0.2 + 0.6 * norm, 0.2 + 0.6 * norm) for norm in normalized_values]

# Create figure and axis
fig, ax = plt.subplots(figsize=(6, 4))

# Plot horizontal bar chart with grayscale gradient
bars = ax.barh(countries, values, color=colors, edgecolor="black")

# Apply finer texture (denser hatching) to Bolivia
for bar, country in zip(bars, countries):
    if country == "Bolivia":
        bar.set_hatch("//////")  # Denser diagonal hatching

# Add labels
for bar, value in zip(bars, values):
    ax.text(value + 0.5, bar.get_y() + bar.get_height()/2, f"{value}", va='center', fontsize=10, color="black")

# Adjust limits and layout
ax.set_xlim(0, 35)
ax.set_xlabel("In Percent of GDP")
ax.invert_yaxis()  # Invert order of y-axis to match the image
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.xaxis.set_ticks_position('bottom')

# Save and display
plt.tight_layout()
plt.show()

# %%
# Create figure and axis with high resolution
fig, ax = plt.subplots(figsize=(6, 4), dpi=300)  # Higher DPI for better quality

# Plot horizontal bar chart with grayscale gradient
bars = ax.barh(countries, values, color=colors, edgecolor="black")

# Apply finer texture (denser hatching) to Bolivia
for bar, country in zip(bars, countries):
    if country == "Bolivia":
        bar.set_hatch("//////")  # Denser diagonal hatching

# Add labels with enhanced readability
for bar, value in zip(bars, values):
    ax.text(value + 0.3, bar.get_y() + bar.get_height()/2, f"{value}", 
            va='center', fontsize=10, color="black", fontweight='bold')

# Adjust limits and layout for a cleaner appearance
ax.set_xlim(0, 35)
ax.set_xlabel("%", fontsize=12, fontweight='bold')
ax.tick_params(axis='both', which='major', labelsize=10)
ax.invert_yaxis()  # Invert order of y-axis to match the image

# Improve aesthetics by removing unnecessary spines
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.xaxis.set_ticks_position('bottom')

# Save the figure in high resolution
output_path = "tax_revenue_high_res.png"
plt.savefig(output_path, dpi=600, bbox_inches='tight', transparent=True)

# Display the final improved plot
plt.show()

# Provide the high-resolution image file link
output_path
# Out:
# 'tax_revenue_high_res.png'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the image
countries = ["Brasil", "Argentina", "Uruguay", "Chile", "Bolivia", "Ecuador", "Colombia", "Peru", "Paraguay"]
values = [33.3, 29.6, 26.6, 23.9, 23.7, 20.9, 19.7, 19.2, 14.7]

# Normalize values for a grayscale gradient effect
normalized_values = (np.array(values) - min(values)) / (max(values) - min(values))

# Create grayscale shades based on values
colors = [(0.2 + 0.6 * norm, 0.2 + 0.6 * norm, 0.2 + 0.6 * norm) for norm in normalized_values]

# Configure font settings for LaTeX-like appearance
plt.rcParams.update({
    "font.family": "serif",       # Use serif font similar to LaTeX
    "font.size": 12,              # Standard academic font size
    "axes.labelsize": 14,         # Larger axis labels for readability
    "axes.titlesize": 14,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12
})

# Create figure and axis with high resolution
fig, ax = plt.subplots(figsize=(6, 4), dpi=300)

# Plot horizontal bar chart with grayscale gradient
bars = ax.barh(countries, values, color=colors, edgecolor="black")

# Apply finer texture (denser hatching) to Bolivia
for bar, country in zip(bars, countries):
    if country == "Bolivia":
        bar.set_hatch("//////")  # Denser diagonal hatching

# Add labels with enhanced readability
for bar, value in zip(bars, values):
    ax.text(value + 0.3, bar.get_y() + bar.get_height()/2, f"{value}", 
            va='center', fontsize=12, color="black")

# Adjust limits and layout for a cleaner appearance
ax.set_xlim(0, 35)
ax.set_xlabel("In Percent of GDP", fontsize=14)
ax.tick_params(axis='both', which='major', labelsize=12)
ax.invert_yaxis()  # Invert order of y-axis to match the image

# Improve aesthetics by removing unnecessary spines
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.xaxis.set_ticks_position('bottom')

# Save the figure in high resolution
output_path = "tax_revenue_high_res.png"
plt.savefig(output_path, dpi=600, bbox_inches='tight', transparent=True)

# Display the final improved plot
plt.show()

# Provide the high-resolution image file link
output_path
# Out:
# 'tax_revenue_high_res.png'

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# Data for the plot
countries = ["Chile", "Ecuador", "Bolivia", "Peru", "Uruguay", "Paraguay", "Brasil", "Argentina", "Colombia"]
changes_2022 = [1.70, 1.47, 1.04, 1.02, 0.95, 0.80, 0.76, 0.59, 0.48]
changes_2021 = [2.97, 0.77, 0.48, 2.80, -1.02, 0.36, 2.05, -0.70, 0.43]

# Normalize values for a lighter grayscale gradient effect
normalized_values_2022 = (np.array(changes_2022) - min(changes_2022)) / (max(changes_2022) - min(changes_2022))
lighter_colors_2022 = [(0.5 + 0.4 * norm, 0.5 + 0.4 * norm, 0.5 + 0.4 * norm) for norm in normalized_values_2022]

normalized_values_2021 = (np.array(changes_2021) - min(changes_2021)) / (max(changes_2021) - min(changes_2021))
lighter_colors_2021 = [(0.5 + 0.4 * norm, 0.5 + 0.4 * norm, 0.5 + 0.4 * norm) for norm in normalized_values_2021]

# Create figure and axis with high resolution
fig, ax = plt.subplots(figsize=(8, 5), dpi=300)

# Plot horizontal bar chart with lighter grayscale gradient for 2022 changes
bars = ax.bar(countries, changes_2022, color=lighter_colors_2022, edgecolor="black")

# Apply texture (hatching) to Bolivia
for bar, country in zip(bars, countries):
    if country == "Bolivia":
        bar.set_hatch("//////")  # Denser diagonal hatching

# Add larger circles for 2021 values with lighter grayscale colors
circle_radius = 0.35  # Keep circles large for readability
for i, country in enumerate(countries):
    circle = plt.Circle((i, changes_2021[i]), circle_radius, color=lighter_colors_2021[i], ec="black", lw=1.5, zorder=3)
    ax.add_patch(circle)
    # Add text inside the circle
    ax.text(i, changes_2021[i], f"{changes_2021[i]:.2f}", fontsize=10,
            ha='center', va='center', color="black")

# Add text labels for bars (2022), ensuring proper spacing
for bar, value in zip(bars, changes_2022):
    ax.text(bar.get_x() + bar.get_width()/2, value + 0.4, f"{value:.2f}", 
            ha='center', fontsize=10, color="black")

# Adjust x-axis labels
ax.set_xticks(range(len(countries)))
ax.set_xticklabels(countries, rotation=45, ha="right")

# Set y-axis limit to 4 as requested
ax.set_ylim(-2.5, 4)

# Labels
ax.set_ylabel("Percentage Points", fontsize=12)

# Improve aesthetics
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# Save the figure in high resolution
output_path = "tax_changes_2021_2022_ymax4.png"
plt.savefig(output_path, dpi=600, bbox_inches='tight', transparent=True)

# Display the final improved plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data (Replace with actual data if available)
years = np.arange(2005, 2024)
#national_values = [0.60, 0.59, 0.56, 0.52, 0.50, 0.47, 0.47, 0.47, 0.48, 0.48, 0.46, 0.46, 0.43, 0.42, 0.45, 0.42, 0.43, 0.43]
#urban_values = [0.54, 0.53, 0.51, 0.50, 0.47, 0.45, 0.41, 0.42, 0.42, 0.42, 0.41, 0.41, 0.38, 0.39, 0.41, 0.38, 0.39, 0.39]
#rural_values = [0.66, 0.64, 0.64, 0.56, 0.53, 0.54, 0.53, 0.53, 0.52, 0.54, 0.54, 0.49, 0.47, 0.48, 0.48, 0.47, 0.48, 0.47]

national_values=[0.600,	0.592,	0.564,	0.517,	0.502,	0.484,	0.466,	0.471,	0.478,	0.477,	0.465,	0.464,	0.456,	0.433,	0.425,	0.452,	0.420,	0.426,	0.434]
urban_values=[0.539,	0.531,	0.507,	0.466,	0.451,	0.430,	0.409,	0.416,	0.420,	0.424,	0.419,	0.405,	0.398,	0.378,	0.386,	0.411,	0.383,	0.387,	0.396]
rural_values=[0.659,	0.640,	0.636,	0.555,	0.534,	0.538,	0.542,	0.543,	0.533,	0.534,	0.518,	0.544,	0.544,	0.493,	0.471,	0.484,	0.478,	0.470,	0.473]




# Normalize marker sizes for better visibility
marker_sizes = np.linspace(100, 300, len(years))

# Configure font settings for LaTeX-like appearance
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 12,
    "axes.labelsize": 14,
    "axes.titlesize": 14,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10
})

# Create figure and axis with high resolution
fig, ax = plt.subplots(figsize=(9, 5), dpi=300)

# Plot lines with distinct markers and grayscale colors (without extra circles)
ax.plot(years, national_values, linestyle="-", color="black", marker="o", markersize=5, label="National")
ax.plot(years, urban_values, linestyle="--", color="gray", marker="s", markersize=5, label="Urban Area")
ax.plot(years, rural_values, linestyle="-.", color="darkgray", marker="^", markersize=5, label="Rural Area")

# Add value labels above points
for x, y in zip(years, national_values):
    ax.text(x, y + 0.01, f"{y:.2f}", ha="center", fontsize=9, color="black")

for x, y in zip(years, urban_values):
    ax.text(x, y - 0.02, f"{y:.2f}", ha="center", fontsize=9, color="black")

for x, y in zip(years, rural_values):
    ax.text(x, y + 0.01, f"{y:.2f}", ha="center", fontsize=9, color="black")

# Adjust x-axis labels
ax.set_xticks(years)
ax.set_xticklabels(years, rotation=45, ha="right")

# Set y-axis limit
ax.set_ylim(0.3, 0.7)

# Labels
ax.set_xlabel("Year")
ax.set_ylabel("Index Value")

# Improve aesthetics
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.legend(loc="upper right", frameon=False, fontsize=12)

# Save the figure in high resolution
output_path = "gini_index_area.png"
plt.savefig(output_path, dpi=600, bbox_inches='tight', transparent=True)

# Display the final improved plot
plt.show()

# Provide the high-resolution image file link
output_path
# Out:
# 'gini_index_area.png'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos
years = np.arange(2005, 2024)  # Hasta 2023
percentile_90_10 = [30.5, 23.6, 19.0, 13.9, 14.7, 11.4, 12.7, 11.5, 11.7, 10.4, 12.2, 11.1, 9.6, 7.9, 9.3, 7.6, 8.0, 8.0, 8.2]  # Añadido 2023
other_series = [4.3, 4.1, 3.9, 3.2, 2.9, 2.9, 2.9, 2.9, 3.0, 2.8, 2.8, 2.8, 2.7, 2.6, 2.8, 2.6, 2.7, 2.7, 2.8]  # Añadido 2023

# Crear figura y ejes
fig, ax1 = plt.subplots(figsize=(10, 6), dpi=300)

# Graficar la primera serie (Percentil 90 / 10) con esferas más grandes
ax1.plot(years, percentile_90_10, color='black', marker='o', markersize=10, linewidth=2, label="Percentil 90 / Percentil 10")
ax1.set_ylabel("Percentil 90 / 10", fontsize=14, color='black')
ax1.set_ylim(5, 40)  # Ajustar el límite del eje hasta 40
ax1.tick_params(axis='y', labelsize=12, colors='black')
ax1.spines['left'].set_color('black')
ax1.spines['bottom'].set_color('black')

# Eje secundario para la otra serie con esferas más grandes
ax2 = ax1.twinx()
ax2.plot(years, other_series, color='gray', marker='o', markersize=10, linewidth=2, linestyle='dashed', label="Otra serie")
ax2.set_ylabel("Otra serie", fontsize=14, color='gray')
ax2.set_ylim(1, 5)
ax2.tick_params(axis='y', labelsize=12, colors='gray')
ax2.spines['right'].set_color('gray')

# Etiquetas en los puntos
for i, txt in enumerate(percentile_90_10):
    ax1.text(years[i], percentile_90_10[i] + 0.5, str(txt), ha='center', fontsize=10, color='black')

for i, txt in enumerate(other_series):
    ax2.text(years[i], other_series[i] + 0.1, str(txt), ha='center', fontsize=10, color='gray')

# Configurar ejes y título
ax1.set_xticks(years)
ax1.set_xticklabels(years, rotation=45, fontsize=12)
ax1.set_xlabel("Año", fontsize=14)
ax1.grid(True, linestyle='--', alpha=0.6)

# Agregar leyendas
ax1.legend(loc="upper left", fontsize=12, frameon=False)
ax2.legend(loc="upper right", fontsize=12, frameon=False)

# Guardar en alta resolución
output_path = "academic_plot_final.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight', transparent=True)

# Mostrar la imagen
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configurar estilo de fuente similar a LaTeX sin usar compilador externo
plt.rcParams.update({
    "text.usetex": False,  # Evitar dependencias de LaTeX externo
    "font.family": "serif",
    "font.size": 14
})

# Datos actualizados
years = np.arange(2005, 2024)  # Desde 2005 hasta 2023

percentile_90_10 = [30.49, 23.63, 19.02, 13.91, 14.72, 13.06, 11.41, 12.74, 11.48, 11.67, 
                    10.40, 12.19, 11.13, 9.61, 7.88, 9.30, 7.64, 7.99, 8.03]

percentile_90_50 = [4.31, 4.12, 3.94, 3.19, 2.95, 2.92, 2.89, 2.87, 2.87, 2.96, 
                    2.81, 2.85, 2.79, 2.67, 2.64, 2.84, 2.64, 2.65, 2.75]

# Crear figura y ejes
fig, ax1 = plt.subplots(figsize=(10, 6), dpi=300)

# Graficar la primera serie (Percentil 90 / 10) con esferas más grandes
ax1.plot(years, percentile_90_10, color='black', marker='o', markersize=10, linewidth=2, label=r"Percentil 90 / Percentil 10")
ax1.set_ylabel(r"Percentil 90 / 10", fontsize=14, color='black')
ax1.set_ylim(5, 40)  # Ajustar el límite del eje hasta 40
ax1.tick_params(axis='y', labelsize=12, colors='black')
ax1.spines['left'].set_color('black')
ax1.spines['bottom'].set_color('black')

# Eje secundario para la otra serie con esferas más grandes
ax2 = ax1.twinx()
ax2.plot(years, percentile_90_50, color='gray', marker='o', markersize=10, linewidth=2, linestyle='dashed', label=r"Percentil 90 / Percentil 50")
ax2.set_ylabel(r"Percentil 90 / 50", fontsize=14, color='gray')
ax2.set_ylim(1, 5)
ax2.tick_params(axis='y', labelsize=12, colors='gray')
ax2.spines['right'].set_color('gray')

# Etiquetas en los puntos
for i, txt in enumerate(percentile_90_10):
    ax1.text(years[i], percentile_90_10[i] + 1.1, f"{txt:.2f}", ha='center', fontsize=10, color='black')

for i, txt in enumerate(percentile_90_50):
    ax2.text(years[i], percentile_90_50[i] + 0.2, f"{txt:.2f}", ha='center', fontsize=10, color='gray')
    


# Configurar ejes y título
ax1.set_xticks(years)
ax1.set_xticklabels(years, rotation=45, fontsize=12)
ax1.set_xlabel(r"Year", fontsize=14)
ax1.grid(True, linestyle='--', alpha=0.6)

# Agregar leyendas
ax1.legend(loc="upper left", fontsize=12, frameon=False)
ax2.legend(loc="upper right", fontsize=12, frameon=False)

# Guardar en alta resolución
output_path = "percentil90_10_50.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight', transparent=True)

# Mostrar la imagen
plt.show()

# %% [markdown]
# ### Tablas Heatmap

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Configurar estilo de fuente similar a LaTeX sin usar compilador externo
plt.rcParams.update({
    "text.usetex": False,  # Evitar dependencias de LaTeX externo
    "font.family": "serif",
    "font.size": 14
})

# Datos de la tabla
data = {
    "-3p.p.": [-0.03, -0.02, -0.06, -0.01, -0.02, 0.10, 0.13, 0.10, 0.10, -0.21, -0.04],
    "-2p.p.": [-0.03, -0.01, -0.05, 0.05, -0.06, 0.07, 0.09, 0.10, 0.10, -0.12, -0.02],
    "-1p.p.": [-0.01, 0.00, -0.02, -0.01, -0.03, 0.09, 0.01, 0.00, 0.00, -0.06, -0.01],
    "+1p.p.": [0.00, 0.03, -0.02, 0.00, -0.03, 0.02, -0.03, 0.00, 0.00, 0.10, 0.01],
    "+2p.p.": [0.02, 0.00, 0.02, 0.00, 0.03, -0.03, -0.09, -0.10, 0.00, 0.17, 0.02],
    "+3p.p.": [0.02, 0.05, -0.04, 0.06, -0.06, -0.01, -0.10, -0.10, 0.00, 0.25, 0.03]
}

# Índices de las filas
index_labels = ["Decil 1", "Decil 2", "Decil 3", "Decil 4", "Decil 5", "Decil 6", 
                "Decil 7", "Decil 8", "Decil 9", "Decil 10", "Gini"]

# Crear DataFrame
df = pd.DataFrame(data, index=index_labels)

# Crear la figura y el heatmap con tonos de gris con encabezado claro
plt.figure(figsize=(10, 6), dpi=300)
ax = sns.heatmap(df, annot=True, cmap="Greys", linewidths=0.5, fmt=".2f", cbar=True)

# Configurar títulos y etiquetas con estilo similar a LaTeX
plt.title(r"\textbf{Impacto de cambios en $\tau_l$ por decil}", fontsize=14, pad=20)
plt.xlabel(r"\textbf{Cambios de $\tau_l$}", fontsize=12, labelpad=10)
plt.ylabel(r"\textbf{Deciles}", fontsize=12, labelpad=10)

# Ajustar encabezado para mayor claridad
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')

# Guardar la imagen en alta resolución
output_path = "heatmap_gris_latex_encabezado.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight', transparent=True)

# Mostrar la imagen
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Configurar estilo de fuente similar a LaTeX sin usar compilador externo
plt.rcParams.update({
    "text.usetex": False,  # Evitar dependencias de LaTeX externo
    "font.family": "serif",
    "font.size": 14
})

# Datos de la tabla
data = {
    "-3p.p.": [-0.03, -0.02, -0.06, -0.01, -0.02, 0.10, 0.13, 0.10, 0.10, -0.21, -0.04],
    "-2p.p.": [-0.03, -0.01, -0.05, 0.05, -0.06, 0.07, 0.09, 0.10, 0.10, -0.12, -0.02],
    "-1p.p.": [-0.01, 0.00, -0.02, -0.01, -0.03, 0.09, 0.01, 0.00, 0.00, -0.06, -0.01],
    "+1p.p.": [0.00, 0.03, -0.02, 0.00, -0.03, 0.02, -0.03, 0.00, 0.00, 0.10, 0.01],
    "+2p.p.": [0.02, 0.00, 0.02, 0.00, 0.03, -0.03, -0.09, -0.10, 0.00, 0.17, 0.02],
    "+3p.p.": [0.02, 0.05, -0.04, 0.06, -0.06, -0.01, -0.10, -0.10, 0.00, 0.25, 0.03]
}

# Índices de las filas
index_labels = ["Decil 1", "Decil 2", "Decil 3", "Decil 4", "Decil 5", "Decil 6", 
                "Decil 7", "Decil 8", "Decil 9", "Decil 10", "Gini"]

# Crear DataFrame
df = pd.DataFrame(data, index=index_labels)

# Crear la figura y el heatmap con tonos de gris con encabezado claro
plt.figure(figsize=(10, 6), dpi=300)
ax = sns.heatmap(df, annot=True, cmap="Greys", linewidths=0.5, fmt=".2f", cbar=True)

# Configurar títulos y etiquetas con estilo similar a LaTeX
plt.title("Impacto de cambios en $τ_\ell$ por decil", fontsize=14, pad=20)
plt.xlabel("Cambios de τ_l", fontsize=12, labelpad=10)
plt.ylabel("Deciles", fontsize=12, labelpad=10)

# Ajustar encabezado para mayor claridad
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')

# Guardar la imagen en alta resolución
output_path = "heatmap_gris_latex_encabezado.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight', transparent=True)

# Mostrar la imagen
plt.show()
# Out:
# <>:34: SyntaxWarning: invalid escape sequence '\e'
# <>:34: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\CESAR\AppData\Local\Temp\ipykernel_10184\112330122.py:34: SyntaxWarning: invalid escape sequence '\e'
#   plt.title("Impacto de cambios en $τ_\ell$ por decil", fontsize=14, pad=20)
